# %%
import cv2
import tkinter as tk
from tkinter import messagebox, simpledialog
import os
import re

# Global variables
capturing = False
capture_count = 0
save_folder = "captured_raw_photos"
capture_subfolder = None  # Will be set by user choice
cap = None

# Ensure base folder exists
os.makedirs(save_folder, exist_ok=True)

# %%
def get_latest_image_number(folder_path):
    """Find the highest numbered image in the folder."""
    if not os.path.exists(folder_path):
        return 0

    max_num = 0
    for filename in os.listdir(folder_path):
        match = re.match(r'image_(\d+)\.jpg$', filename)
        if match:
            num = int(match.group(1))
            if num > max_num:
                max_num = num
    return max_num

# %%
def prompt_for_folder():
    """Ask user to choose group, individual, or exit."""
    global capture_subfolder, capture_count, cap, capturing

    while True:
        choice = simpledialog.askstring("Choose Option", "Enter:\n1 for Group\n2 for Individual\ne to Exit")
        if choice == "1":
            capture_subfolder = "group"
            break
        elif choice == "2":
            capture_subfolder = "individual"
            break
        elif choice == "e":
            capturing = False
            return
        
    # Set counter based on selected folder
    current_folder = os.path.join(save_folder, capture_subfolder)
    capture_count = get_latest_image_number(current_folder)
    print(f"Switched to folder: {capture_subfolder}, starting from image {capture_count + 1}")

# %%
def start_capture():
    global cap, capturing, capture_count

    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        messagebox.showerror("Error", "Could not access the webcam.")
        return
    
    capturing = True
    prompt_for_folder()

    print("Webcam started. Press 'c' to capture, 'Enter' to switch folder or exit.")

    while capturing:
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture image.")
            break

        # ✅ Show the webcam feed in a window
        cv2.imshow("Webcam", frame)

        key = cv2.waitKey(1) & 0xFF

        if key == ord('c') and capture_subfolder:
            capture_count += 1
            folder_path = os.path.join(save_folder, capture_subfolder)
            os.makedirs(folder_path, exist_ok=True)
            filename = os.path.join(folder_path, f"image_{capture_count}.jpg")
            success = cv2.imwrite(filename, frame)
            if success:
                print(f"Captured: {filename}")
            else:
                print("Failed to save image.")
                capture_count -= 1

        elif key == 13:  # Enter key
            prompt_for_folder()

        elif key == ord('e'):
            capturing = False

    cap.release()
    cv2.destroyAllWindows()
    print("Capture session ended.")

# %%
# GUI Setup
window = tk.Tk()
window.title("Auto Webcam Capture")

instructions = tk.Label(window, text="Webcam starts automatically.\nPress 'Enter' to choose folder (Group/Individual/Exit).\nPress 'c' to capture images.\nPress 'Enter' again to switch or exit.")
instructions.pack(pady=20)

# Start webcam capture immediately
window.after(100, start_capture)

# Tkinter mainloop
window.mainloop()
# Out:
# Switched to folder: group, starting from image 1
# Webcam started. Press 'c' to capture, 'Enter' to switch folder or exit.
# Captured: captured_raw_photos\group\image_1.jpg
# Captured: captured_raw_photos\group\image_2.jpg
# Captured: captured_raw_photos\group\image_3.jpg
# Captured: captured_raw_photos\group\image_4.jpg
# Captured: captured_raw_photos\group\image_5.jpg
# Captured: captured_raw_photos\group\image_6.jpg
# Captured: captured_raw_photos\group\image_7.jpg
# Captured: captured_raw_photos\group\image_8.jpg
# Captured: captured_raw_photos\group\image_9.jpg
# Captured: captured_raw_photos\group\image_10.jpg
# Captured: captured_raw_photos\group\image_11.jpg
# Captured: captured_raw_photos\group\image_12.jpg
# Captured: captured_raw_photos\group\image_13.jpg
# Captured: captured_raw_photos\group\image_14.jpg
# Captured: captured_raw_photos\group\image_15.jpg
# Captured: captured_raw_photos\group\image_16.jpg
# Captured: captured_raw_photos\group\image_17.jpg
# Captured: captured_raw_photos\group\image_18.jpg
# Captured: captured_raw_photos\group\image_19.jpg
# Captured: captured_raw_photos\group\image_20.jpg
# Captured: captured_raw_photos\group\image_21.jpg
# Captured: captured_raw_photos\group\image_22.jpg
# Captured: captured_raw_photos\group\image_23.jpg
# Captured: captured_raw_photos\group\image_24.jpg
# Captured: captured_raw_photos\group\image_25.jpg
# Captured: captured_raw_photos\group\image_26.jpg
# Captured: captured_raw_photos\group\image_27.jpg
# Captured: captured_raw_photos\group\image_28.jpg
# Captured: captured_raw_photos\group\image_29.jpg
# Captured: captured_raw_photos\group\image_30.jpg
# Captured: captured_raw_photos\group\image_31.jpg
# Captured: captured_raw_photos\group\image_32.jpg
# Captured: captured_raw_photos\group\image_33.jpg
# Captured: captured_raw_photos\group\image_34.jpg
# Captured: captured_raw_photos\group\image_35.jpg
# Captured: captured_raw_photos\group\image_36.jpg
# Captured: captured_raw_photos\group\image_37.jpg
# Captured: captured_raw_photos\group\image_38.jpg
# Captured: captured_raw_photos\group\image_39.jpg
# Captured: captured_raw_photos\group\image_40.jpg
# Captured: captured_raw_photos\group\image_41.jpg
# Captured: captured_raw_photos\group\image_42.jpg
# Captured: captured_raw_photos\group\image_43.jpg
# Captured: captured_raw_photos\group\image_44.jpg
# Captured: captured_raw_photos\group\image_45.jpg
# Captured: captured_raw_photos\group\image_46.jpg
# Captured: captured_raw_photos\group\image_47.jpg
# Captured: captured_raw_photos\group\image_48.jpg
# Captured: captured_raw_photos\group\image_49.jpg
# Captured: captured_raw_photos\group\image_50.jpg
# Switched to folder: individual, starting from image 1
# Captured: captured_raw_photos\individual\image_1.jpg
# Captured: captured_raw_photos\individual\image_2.jpg
# Captured: captured_raw_photos\individual\image_3.jpg
# Captured: captured_raw_photos\individual\image_4.jpg
# Captured: captured_raw_photos\individual\image_5.jpg
# Captured: captured_raw_photos\individual\image_6.jpg
# Captured: captured_raw_photos\individual\image_7.jpg
# Captured: captured_raw_photos\individual\image_8.jpg
# Captured: captured_raw_photos\individual\image_9.jpg
# Captured: captured_raw_photos\individual\image_10.jpg
# Captured: captured_raw_photos\individual\image_11.jpg
# Captured: captured_raw_photos\individual\image_12.jpg
# Captured: captured_raw_photos\individual\image_13.jpg
# Captured: captured_raw_photos\individual\image_14.jpg
# Captured: captured_raw_photos\individual\image_15.jpg
# Captured: captured_raw_photos\individual\image_16.jpg
# Captured: captured_raw_photos\individual\image_17.jpg
# Captured: captured_raw_photos\individual\image_18.jpg
# Captured: captured_raw_photos\individual\image_19.jpg
# Captured: captured_raw_photos\individual\image_20.jpg
# Captured: captured_raw_photos\individual\image_21.jpg
# Captured: captured_raw_photos\individual\image_22.jpg
# Captured: captured_raw_photos\individual\image_23.jpg
# Captured: captured_raw_photos\individual\image_24.jpg
# Captured: captured_raw_photos\individual\image_25.jpg
# Captured: captured_raw_photos\individual\image_26.jpg
# Captured: captured_raw_photos\individual\image_27.jpg
# Captured: captured_raw_photos\individual\image_28.jpg
# Captured: captured_raw_photos\individual\image_29.jpg
# Captured: captured_raw_photos\individual\image_30.jpg
# Captured: captured_raw_photos\individual\image_31.jpg
# Captured: captured_raw_photos\individual\image_32.jpg
# Captured: captured_raw_photos\individual\image_33.jpg
# Captured: captured_raw_photos\individual\image_34.jpg
# Captured: captured_raw_photos\individual\image_35.jpg
# Captured: captured_raw_photos\individual\image_36.jpg
# Captured: captured_raw_photos\individual\image_37.jpg
# Captured: captured_raw_photos\individual\image_38.jpg
# Captured: captured_raw_photos\individual\image_39.jpg
# Captured: captured_raw_photos\individual\image_40.jpg
# Captured: captured_raw_photos\individual\image_41.jpg
# Captured: captured_raw_photos\individual\image_42.jpg
# Captured: captured_raw_photos\individual\image_43.jpg
# Captured: captured_raw_photos\individual\image_44.jpg
# Captured: captured_raw_photos\individual\image_45.jpg
# Captured: captured_raw_photos\individual\image_46.jpg
# Captured: captured_raw_photos\individual\image_47.jpg
# Captured: captured_raw_photos\individual\image_48.jpg
# Captured: captured_raw_photos\individual\image_49.jpg
# Captured: captured_raw_photos\individual\image_50.jpg
# Captured: captured_raw_photos\individual\image_51.jpg
# Captured: captured_raw_photos\individual\image_52.jpg
# Captured: captured_raw_photos\individual\image_53.jpg
# Captured: captured_raw_photos\individual\image_54.jpg
# Captured: captured_raw_photos\individual\image_55.jpg
# Captured: captured_raw_photos\individual\image_56.jpg
# Captured: captured_raw_photos\individual\image_57.jpg
# Captured: captured_raw_photos\individual\image_58.jpg
# Captured: captured_raw_photos\individual\image_59.jpg
# Captured: captured_raw_photos\individual\image_60.jpg
# Captured: captured_raw_photos\individual\image_61.jpg
# Captured: captured_raw_photos\individual\image_62.jpg
# Captured: captured_raw_photos\individual\image_63.jpg
# Captured: captured_raw_photos\individual\image_64.jpg
# Captured: captured_raw_photos\individual\image_65.jpg
# Captured: captured_raw_photos\individual\image_66.jpg
# Captured: captured_raw_photos\individual\image_67.jpg
# Captured: captured_raw_photos\individual\image_68.jpg
# Captured: captured_raw_photos\individual\image_69.jpg
# Captured: captured_raw_photos\individual\image_70.jpg
# Captured: captured_raw_photos\individual\image_71.jpg
# Captured: captured_raw_photos\individual\image_72.jpg
# Captured: captured_raw_photos\individual\image_73.jpg
# Captured: captured_raw_photos\individual\image_74.jpg
# Captured: captured_raw_photos\individual\image_75.jpg
# Captured: captured_raw_photos\individual\image_76.jpg
# Captured: captured_raw_photos\individual\image_77.jpg
# Captured: captured_raw_photos\individual\image_78.jpg
# Captured: captured_raw_photos\individual\image_79.jpg
# Captured: captured_raw_photos\individual\image_80.jpg
# Capture session ended.
